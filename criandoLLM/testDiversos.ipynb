# %%
from dotenv import load_dotenv
import os

# Carrega as variáveis do arquivo .env
load_dotenv()

# Acessa a variável de ambiente
path_raw_model = os.getenv("PATH_RAW_MODEL")
print(f"Path do modelo RAW: {path_raw_model}")
# Out:
# Path do modelo RAW: C:\Users\dsantos\Documents\workspaceStudoLLM\criandoLLM\RAW_MODEL
